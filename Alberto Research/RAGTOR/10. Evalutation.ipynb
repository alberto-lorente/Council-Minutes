# %% [markdown]
# ### Evaluation of the Data Transformations

# %%
from council_rag.data_transformations.text_transformations import generate_groq_summary

# %%
# paste the GROQ_KEY.txt file in the same folder as this notebook
with open("GROQ_KEY.txt", "r") as file:
    groq_key = file.read()

# %%
base_summary_prompt = """Il s'agit d'un texte concernant un projet de géothermie :
TEXTE: 
{}

TÂCHE:
Make a one page summary paying special attention to all the administrative matters like budgets, plans, actions to take in the future, organizational and hierarchical charts, announcements, meetings, contacts, elections, reports and all the related topics to these.

OUTPUT:
Publier directement le résumé en anglais.
""" # added the english output to make the eval easier

# %%
import os
# loading the data from the correct folder
eval_summ_data_path = "Evaluation data/Summaries/"
eval_summ_list_random_pages = os.listdir(eval_summ_data_path)
print(eval_summ_list_random_pages)
# Out:
# ['page_13.pdf', 'page_29.pdf', 'page_35.pdf', 'page_44.pdf']

# %%
from pypdf import PdfReader

# quickly read the content of the pdfs. it is not markdown but it should be okay for the eval
def extract_text_from_pdf(pdf_name, eval_data_path):

    reader = PdfReader(eval_data_path + pdf_name)
    text_page = reader.pages[0].extract_text()
    
    return text_page

text_to_summ = [extract_text_from_pdf(pdf_name, eval_summ_data_path) for pdf_name in eval_summ_list_random_pages]

# %%
# models we could eval from groq
list_models_eval = ["deepseek-r1-distill-qwen-32b", 
                    "deepseek-r1-distill-llama-70b", 
                    "gemma2-9b-it", 
                    "llama-3.3-70b-versatile"]

# %%
from pprint import pprint

# for each page, we generate the summary with each model and we open the page in the browser for easier reference

i = 0
while i < len(text_to_summ[0:2]): # generating the first 2 pages 
    for model in list_models_eval:
        summ = generate_groq_summary(text_to_summ[i], 
                                    base_summary_prompt, 
                                    groq_key, 
                                    model)
        print("SUMMARY OF {} with model: {}".format(eval_summ_list_random_pages[i], model))
        pprint(summ)
        print("\n")
        print("--------------------------------")
        
        # if you prefer openning the txt file instead of reading below. will save into the Evaluation data/Summaries folder
        with open(f"{eval_summ_data_path}summary_{model}_{eval_summ_list_random_pages[i]}.txt") as f: 
            f.write(summ)        
    i += 1
# Out:
# SUMMARY OF page_13.pdf with model: deepseek-r1-distill-qwen-32b
# ('<think>\n'
#  'Okay, let me try to figure out how to approach this. The user has provided a '
#  'detailed transcript from a community council meeting, and they want me to '
#  'create a summary. I need to understand the main points discussed and present '
#  'them in a clear, concise manner.\n'
#  '\n'
#  "First, I'll read through the transcript carefully to identify the key "
#  'topics. It seems there are several sections: discussions about the airport '
#  'development, the hunting rights at Grands Murcins, the Roma settlement plan, '
#  "and the arrival of a new member. There's also a section on general affairs, "
#  'specifically the 2020 activity report.\n'
#  '\n'
#  "I should structure the summary by these main topics. For each section, I'll "
#  'extract the essential points without getting bogged down in the details. For '
#  "example, Franck Beysson's concerns about the long-term airport development "
#  "and the implications of hunting rights. I'll make sure to note the different "
#  "perspectives, like Martine Roffat's explanation about the necessity of "
#  'hunting for ecological balance.\n'
#  '\n'
#  "I also notice that there's a part about the Roma settlement being decided "
#  'without broader community input, which Franck Beysson regrets. This is an '
#  'important point about community engagement. Additionally, the arrival of '
#  'Gilles Passot as a new member is a formality but worth mentioning.\n'
#  '\n'
#  'In the general affairs section, the 2020 report highlights the impact of '
#  'COVID-19 and the various support measures taken. I should summarize these '
#  'initiatives, such as the economic support funds and the continuation of '
#  'public services despite the pandemic.\n'
#  '\n'
#  'I need to ensure that the summary is in French, as the original text is in '
#  "French. I'll use bullet points or numbered lists to make it easy to read, "
#  "but I'll avoid markdown as per the instructions. Instead, I'll present it in "
#  'a clear, organized way, perhaps using headings for each main section.\n'
#  '\n'
#  "I should also be concise. The user doesn't want a word-for-word translation "
#  "but a summary that captures the essence of each discussion. I'll avoid "
#  'including every minor point and focus on the major decisions, concerns, and '
#  'outcomes.\n'
#  '\n'
#  "Lastly, I'll review the summary to make sure it flows logically and covers "
#  'all the critical aspects discussed during the meeting. This way, the user '
#  "gets a comprehensive yet succinct overview of the council's discussions.\n"
#  '</think>\n'
#  '\n'
#  'Voici un résumé des points principaux discutés lors de la réunion du Conseil '
#  'communautaire :\n'
#  '\n'
#  "### 1. **Engagement pour le développement de l'aéroport**\n"
#  "   - Franck Beysson s'est interrogé sur l'engagement à mettre à disposition "
#  "des surfaces pour développer l'animation du site aéroportuaire jusqu'en "
#  "2050, soulignant l'horizon très lointain de ce projet et les enjeux "
#  'climatiques.\n'
#  "   - La dépense sera comptabilisée sur le budget général de l'exercice "
#  'concerné.\n'
#  '\n'
#  '### 2. **Pouvoir seigneurial et chasse aux Grands Murcins**\n'
#  '   - Franck Beysson a évoqué le pouvoir seigneurial du Président, notamment '
#  'en ce qui concerne les droits de chasse sur le site des Grands Murcins.\n'
#  '   - Il a suggéré de réfléchir à une convention renouvelable par tacite '
#  'reconduction, pour en faire un espace de rencontre et de préservation, où la '
#  'chasse pourrait être exclue.\n'
#  '   - Martine Roffat a expliqué que la chasse est organisée pour préserver '
#  "l'équilibre écologique et que les séquences de chasse sont bien annoncées et "
#  'encadrées.\n'
#  "   - Pierre Devedeux a précisé que la chasse n'est pas autorisée sur "
#  "l'ensemble du site et que les secteurs concernés sont bien balisés.\n"
#  '\n'
#  "### 3. **Schéma d'accueil des gens du voyage**\n"
#  '   - Franck Beysson a exprimé son regret que ce schéma ait été décidé et '
#  'acté uniquement au niveau du Bureau délibératif, souhaitant un débat plus '
#  'large en Assemblée communautaire.\n'
#  '\n'
#  '### 4. **Arrivée de Gilles Passot**\n'
#  '   - Gilles Passot, nouveau membre du Conseil communautaire, a été '
#  'accueilli.\n'
#  '\n'
#  "### 5. **Rapport d'activités 2020**\n"
#  "   - Le Président a présenté les grandes lignes du rapport d'activités 2020, "
#  'marqué par :\n'
#  '     - Le renouvellement des exécutifs communaux et intercommunaux.\n'
#  '     - La crise sanitaire et économique due au COVID-19, avec une priorité '
#  "donnée à l'économie (fonds de soutien, aide au tourisme, etc.).\n"
#  '     - Des actions menées malgré la crise, notamment :\n'
#  '       - Transport : attribution de la DSP à Transdev (flotte électrique).\n'
#  '       - Déchets ménagers : extension des consignes de tri.\n'
#  "       - Assainissement : adoption d'un nouveau schéma directeur.\n"
#  '       - Culture : mise en réseau des médiathèques.\n'
#  '       - Santé : production de visières anti-Covid.\n'
#  '       - Grands équipements : validation du centre aqualudique.\n'
#  '\n'
#  '### 6. **Prise de décision**\n'
#  '   - Le Conseil communautaire a pris acte du compte-rendu des pouvoirs '
#  'délégués, comprenant 20 décisions du Président et 27 délibérations du Bureau '
#  'communautaire.')
#
#
# --------------------------------
# SUMMARY OF page_13.pdf with model: deepseek-r1-distill-llama-70b
# ('<think>\n'
#  "Okay, so I'm looking at this document from page 13 out of 49. It's written "
#  'in French, and it seems to be the minutes or a report from a community '
#  'council meeting. There are a few key points here that I need to understand '
#  'and maybe summarize.\n'
#  '\n'
#  'First, Franck Beysson is talking about several decisions related to the '
#  'airport. One of them is about making surfaces available to develop airport '
#  "animation until 2050. He's concerned about this because of existing climate "
#  "issues, thinking that 2050 is too far away. I guess he's worried about the "
#  'long-term environmental impact or maybe the commitment seems too lengthy.\n'
#  '\n'
#  "Then, Franck brings up something about seigneurial power, which he's "
#  "mentioned before. It's about hunting rights granted by the President, "
#  'specifically for educational purposes at the Grands Murcins site. He points '
#  'out that this site is for the public, preservation, tourism, etc., and '
#  'suggests that they should think about making it a meeting space where '
#  "hunting isn't allowed. He mentions that there are plenty of other hunting "
#  'areas in the Côte roannaise region.\n'
#  '\n'
#  'He also regrets that the plan for welcoming travelers was decided only in '
#  'the deliberative bureau and not discussed more widely in the community '
#  'assembly. Martine Roffat responds by saying that hunting schedules at Grands '
#  "Murcins are announced well in advance so the public knows, and it's to "
#  'maintain a balance, preventing overpopulation of wild boars and deer. She '
#  "says it's not to please any federation but to preserve balance.\n"
#  '\n'
#  "Franck counters that the convention doesn't state that; it's about "
#  "authorization for big game hunting, not just controlling pests, and it's for "
#  'educational purposes, not regulation. Pierre Devedeux adds that hunting '
#  "isn't allowed everywhere in Grands Murcins, only in specific areas on "
#  'Sundays from 9 to 11 am, and the rest is safe for walking.\n'
#  '\n'
#  'The council notes the report of delegated powers, with 20 presidential '
#  'decisions and 27 bureau deliberations. Gilles Passot arrives, and they move '
#  'on to general affairs, starting with the 2020 activity report. The president '
#  'outlines that 2020 was marked by renewals of local and intercommunal '
#  'executives, the COVID crisis, and economic impacts. They focused on the '
#  'economy with support funds for businesses and tourism, protection for '
#  'healthcare workers, and maintaining public services like waste collection. '
#  'They also continued other projects despite the pandemic.\n'
#  '\n'
#  'In transport, they awarded a contract to Transdev for electric vehicles. For '
#  'waste, they expanded recycling rules. In sanitation, a new master plan was '
#  'adopted. In culture, they networked media libraries. In health, they '
#  'produced COVID visors. For major equipment, they approved an aquatic leisure '
#  "center. There's a mention of a prefectural decree from December 30, 2019, "
#  'regarding the statutes of Roannais Agglomération.\n'
#  '\n'
#  'So, I need to make sense of all this. It seems like the council is '
#  'discussing various decisions, some controversial, like the airport and '
#  "hunting rights. They're also reporting on the past year's activities, which "
#  'were heavily influenced by COVID.\n'
#  '\n'
#  'I should probably structure this into sections: the airport decision, the '
#  'hunting rights debate, the activity report, and other business. Each section '
#  'can summarize the key points, who said what, and the outcomes or decisions '
#  'made.\n'
#  '\n'
#  'I might need to explain some terms, like "pouvoir seigneurial" or "DSP '
#  'Transport," but maybe that\'s beyond the scope. The main goal is to provide '
#  'a clear, concise summary of the document, highlighting the discussions and '
#  'decisions made by the council.\n'
#  '</think>\n'
#  '\n'
#  'The document from page 13 of 49 outlines key discussions and decisions from '
#  'a community council meeting, focusing on several contentious topics and the '
#  "annual activity report. Here's a structured summary:\n"
#  '\n'
#  '### 1. Airport Development Decision\n'
#  '- **Issue Raised by Franck Beysson**: Concerns about committing resources '
#  'until 2050 for airport animation, citing climate change implications.\n'
#  '- **Outcome**: The council acknowledged the decision but noted environmental '
#  'concerns.\n'
#  '\n'
#  '### 2. Hunting Rights at Grands Murcins\n'
#  "- **Franck Beysson's Concerns**: Questioned the seigneurial power allowing "
#  'hunting for educational purposes, suggesting the site should be a peaceful '
#  'meeting space without hunting.\n'
#  "- **Martine Roffat's Response**: Hunting is scheduled and announced in "
#  'advance to control wildlife, not for sport, emphasizing balance '
#  'preservation.\n'
#  "- **Franck's Counterpoint**: The convention allows big game hunting, not "
#  'just pest control, and is for education, not regulation.\n'
#  "- **Pierre Devedeux's Clarification**: Hunting is restricted to specific "
#  'areas and times, ensuring public safety elsewhere.\n'
#  '\n'
#  "### 3. Travelers' Accommodation Plan\n"
#  "- **Franck's Regret**: The plan was decided in a bureau meeting without "
#  'broader community discussion.\n'
#  '- **Outcome**: No further action noted, but highlighted the need for wider '
#  'consultation.\n'
#  '\n'
#  '### 4. 2020 Activity Report\n'
#  '- **Key Points by the President**:\n'
#  '  - **Context**: Marked by political renewals and COVID-19 impacts.\n'
#  '  - **Economic Measures**: Support funds for businesses and tourism, '
#  'healthcare worker protection.\n'
#  '  - **Public Services**: Continued waste management and other essential '
#  'services.\n'
#  '  - **Projects**:\n'
#  '    - **Transport**: Transdev contract for electric vehicles.\n'
#  '    - **Waste Management**: Expanded recycling.\n'
#  '    - **Sanitation**: New master plan.\n'
#  '    - **Culture**: Networked media libraries.\n'
#  '    - **Health**: Produced COVID visors.\n'
#  '    - **Leisure**: Approved aquatic center.\n'
#  '- **Mention of Prefectural Decree**: Referenced the statutes of Roannais '
#  'Agglomération.\n'
#  '\n'
#  '### Conclusion\n'
#  'The council addressed controversial decisions on airport and hunting '
#  'policies, emphasizing environmental and public access concerns. The 2020 '
#  'report highlighted resilience and adaptability amidst the pandemic, with '
#  'continued investments in key sectors.')
#
#
# --------------------------------
# SUMMARY OF page_13.pdf with model: gemma2-9b-it
# ('## Résumé de la partie du texte\n'
#  '\n'
#  "Ce document provient d'une séance du Conseil communautaire de Roannais "
#  'Agglomération. \n'
#  '\n'
#  '**Voici les points importants discutés:**\n'
#  '\n'
#  '* **Comptabilisation des dépenses:** Un point est soulevé concernant la '
#  "comptabilisation des dépenses sur le budget général de l'exercice.\n"
#  '* **Remarques de Franck Beysson:**\n'
#  "    * **Animation aéroportuaire:** Franck Beysson s'interroge sur la logique "
#  "de réserver des surfaces pour l'animation de l'aéroport jusqu'en 2050 compte "
#  'tenu des enjeux climatiques.\n'
#  '    * **Pouvoir seigneurial et chasse aux Grands Murcins :** Il demande une '
#  'réflexion sur la convention autorisant la chasse aux Grands Murcins, site '
#  'ouvert au public et classé comme espace de préservation et de tourisme. Il '
#  'suggère de transformer ce site en espace de rencontre apaisé, exempt de '
#  'chasse.\n'
#  "    * **Schéma d'accueil des gens du voyage :** Franck Beysson regrette que "
#  'ce schéma ait été décidé uniquement au niveau du Bureau délibératif et non '
#  'débattu en assemblée communautaire. \n'
#  '* **Réponses de Martine Roffat et Pierre Devedeux:**\n'
#  '    *  Martine Roffat explique que les séquences de chasse aux Grands '
#  "Murcins sont organisées pour préserver l'équilibre écologique, en contrôlant "
#  'les populations de sangliers et de chevreuils.\n'
#  "    * Pierre Devedeux précise que la chasse n'est pas autorisée sur "
#  "l'ensemble du massif et que les périodes sont limitées, balisées et "
#  'communiquées au public.\n'
#  '* **Adoption du compte-rendu:** Le Conseil communautaire prend acte du '
#  'compte-rendu des pouvoirs délégués du président et du bureau communautaire.\n'
#  '\n'
#  ' **Autres points couverts dans le document:**\n'
#  '\n'
#  '* Arrivée de Gilles Passot\n'
#  "* Présentation du rapport d'activité 2020 par le président.\n"
#  '\n'
#  '\n')
#
#
# --------------------------------
# SUMMARY OF page_13.pdf with model: llama-3.3-70b-versatile
# ("Il s'agit d'un extrait de compte-rendu de réunion du Conseil communautaire "
#  'de Roannais Agglomération. Voici les points clés qui ressortent de ce texte '
#  ':\n'
#  '\n'
#  "1. **Remarques de Franck Beysson** : il s'interroge sur plusieurs décisions, "
#  "notamment la mise à disposition de surfaces pour développer l'animation du "
#  "site aéroportuaire jusqu'en 2050, compte tenu des enjeux climatiques. Il "
#  'évoque également les droits de chasse attribués par le Président sur le site '
#  'des Grands Murcins et propose que ce site devienne un espace de rencontre et '
#  'de préservation sans chasse.\n'
#  '2. **Réponses de Martine Roffat et Pierre Devedeux** : ils expliquent que '
#  "les séquences de chasse aux Grands Murcins sont annoncées à l'avance pour "
#  "préserver l'équilibre de la faune et de la flore. Ils précisent que la "
#  "chasse n'est pas autorisée sur toute la surface des Grands Murcins et que "
#  'les secteurs de chasse sont définis.\n'
#  '3. **Compte-rendu des pouvoirs délégués** : le Conseil communautaire prend '
#  'acte du compte-rendu des pouvoirs délégués au Président et au bureau '
#  'communautaire, comprenant 20 décisions du Président et 27 délibérations du '
#  'bureau.\n'
#  "4. **Rapport d'activités 2020** : le Président présente les grandes lignes "
#  "du rapport d'activité 2020, marqué par le renouvellement des exécutifs "
#  'communaux et intercommunal, la crise sanitaire et économique du COVID-19, et '
#  "les actions menées pour soutenir l'économie et poursuivre les services "
#  'publics.\n'
#  '\n'
#  'En résumé, ce compte-rendu de réunion aborde des sujets tels que la gestion '
#  'des sites aéroportuaires et des espaces naturels, les droits de chasse, et '
#  'les actions menées pour faire face à la crise sanitaire et économique.')
#
#
# --------------------------------
# SUMMARY OF page_29.pdf with model: deepseek-r1-distill-qwen-32b
# ('<think>\n'
#  "D'accord, je dois analyser les données financières fournies pour le budget "
#  '2021. Je vais commencer par examiner les recettes, les dépenses et les '
#  'ajustements mentionnés.\n'
#  '\n'
#  "Tout d'abord, dans la section des recettes, je vois plusieurs ajustements "
#  "comme l'ajustement des recettes de l'aviation civile, le reversement de la "
#  "taxe aéroportuaire, et d'autres éléments comme les amortissements et "
#  "provisions. Je dois m'assurer que ces ajustements sont correctement intégrés "
#  'dans les totaux.\n'
#  '\n'
#  'Ensuite, pour les dépenses, il y a des investissements supplémentaires et '
#  'des ajustements de crédits, notamment des reports sur 2022. Il semble y '
#  'avoir des changements significatifs dans les emprunts et les subventions, ce '
#  "qui pourrait affecter l'équilibre du budget.\n"
#  '\n'
#  'Je dois vérifier si les totaux des recettes et des dépenses correspondent '
#  "après ces ajustements. En particulier, je dois m'assurer que les reports et "
#  "les annulations sont correctement traités et qu'il n'y a pas d'écarts "
#  'inexpliqués.\n'
#  '\n'
#  'Enfin, je vais comparer les totaux des sections recettes et dépenses pour '
#  "m'assurer que le budget est équilibré ou si des ajustements supplémentaires "
#  'sont nécessaires.\n'
#  '</think>\n'
#  '\n'
#  'Pour analyser les données financières du budget 2021, procédons étape par '
#  'étape :\n'
#  '\n'
#  '### **1. Analyse des Recettes**\n'
#  '\n'
#  '**Recettes réelles :**\n'
#  '- **Produits des services :** 311 000,00 €\n'
#  '- **Dotations, subventions et participations :** 124 600,00 €\n'
#  '- **Autres produits de gestion courante :** 571 110,00 € (dont 536 710,00 € '
#  'de participation du budget général)\n'
#  '- **Produits exceptionnels :** 40 000,00 €\n'
#  '- **Reprises sur amortissements et provisions :** 12 486,00 €\n'
#  '\n'
#  '**Total des recettes réelles :** 1 006 710,00 €\n'
#  '\n'
#  '**Autres recettes :**\n'
#  '- **Amortissements :** 10 000,00 €\n'
#  '\n'
#  '**Total des recettes :** 1 016 710,00 €\n'
#  '\n'
#  '### **2. Analyse des Dépenses**\n'
#  '\n'
#  '**Dépenses réelles :**\n'
#  '- **Emprunts et dettes :** 49 600,00 €\n'
#  '- **Immobilisations corporelles :** 138 300,00 €\n'
#  '- **Autres travaux aéroport :** 275 000,00 €\n'
#  '- **Immobilisations incorporelles :** 0,00 €\n'
#  '- **Immobilisations en cours :** 185 000,00 €\n'
#  '\n'
#  '**Total des dépenses réelles :** 462 900,00 €\n'
#  '\n'
#  '**Autres dépenses :**\n'
#  '- **Amortissements :** 10 000,00 €\n'
#  '- **Opérations patrimoniales :** 3 100,00 €\n'
#  '\n'
#  '**Total des dépenses :** 472 900,00 €\n'
#  '\n'
#  '### **3. Equilibre du Budget**\n'
#  '\n'
#  '**Recettes totales :** 1 016 710,00 €  \n'
#  '**Dépenses totales :** 472 900,00 €  \n'
#  '\n'
#  '**Solde du budget :**  \n'
#  '1 016 710,00 € - 472 900,00 € = **543 810,00 €**\n'
#  '\n'
#  'Ce solde positif indique un excédent de 543 810,00 € dans le budget 2021.\n'
#  '\n'
#  '### **4. Observations et Ajustements**\n'
#  '\n'
#  '- **Ajustements en recettes :** Les ajustements tels que les amortissements, '
#  'les provisions et les reports ont été correctement intégrés.\n'
#  '- **Ajustements en dépenses :** Les reports sur 2022 et les annulations des '
#  'crédits ont été pris en compte, ce qui affecte le solde du budget.\n'
#  '- **Equilibre :** Le budget semble équilibré avec un excédent significatif, '
#  'ce qui est une bonne indication de gestion financière.\n'
#  '\n'
#  '### **5. Conclusion**\n'
#  '\n'
#  'Le budget 2021 présente un excédent de 543 810,00 €, reflétant une gestion '
#  'financière saine avec des ajustements et reports appropriés.')
#
#
# --------------------------------
# SUMMARY OF page_29.pdf with model: deepseek-r1-distill-llama-70b
# ('<think>\n'
#  "Okay, so I'm trying to understand this budget document for BP 2021. It looks "
#  "like it's in French, which I can read a bit, but some terms might be tricky. "
#  'Let me start by breaking it down section by section.\n'
#  '\n'
#  "First, there's a section about recettes, which I think means revenues. They "
#  "mention adjustments in aviation revenues and some tax reversals. There's a "
#  'line about amortissement des subventions, which I think is about '
#  "depreciating subsidies. Then there's something about provisions for a time "
#  'savings account and depreciation of current assets. Also, a decrease in a '
#  'subsidy from the general budget. \n'
#  '\n'
#  'Looking at the numbers, under "RECETTES BP 2021 DM", the categories are 70, '
#  '74, 75, 77, 78. Each has some figures with pluses and minuses. For example, '
#  '70 - Produits des services is 311,000 euros, but then a decrease of 125,000. '
#  'Then 74 has 124,600 with a decrease of 31,000 and another 20,400. 75 has '
#  '571,110 with a small decrease and a bigger decrease of 80,500. \n'
#  '\n'
#  'I see the total recettes réelles is 1,006,710 euros with some adjustments. '
#  'Then amortissements add another 10,000, making the total recettes 1,016,710. '
#  "But there are some negative numbers too, like -115,464 and -39,600. I'm not "
#  'sure how these negatives affect the total. Maybe they are adjustments from '
#  'previous DMs?\n'
#  '\n'
#  "Moving on to the investment section, dépenses d'investissement "
#  'supplémentaires. They mention electrical works by SIEL, some taxes, and '
#  'fees. Also, more amortissement des subventions and study costs. Then there '
#  'are credit adjustments for reports to 2022, like road diversion, new airline '
#  'line, runway resurfacing, and cancellation of a general budget advance.\n'
#  '\n'
#  'Looking at the numbers under "DEPENSES BP 2021 DM", categories 16, 21, 601, '
#  '608. Each has significant figures with some increases and decreases. For '
#  'example, 16 - Emprunts has 49,600 but then a big jump to 381,650 and a '
#  'decrease of 382,250. The details under each category show specific '
#  'expenditures like matériel aéroport, travaux aéroport, etc.\n'
#  '\n'
#  'The total dépenses réelles is 462,900 with some amortissements adding up. '
#  "Then there's a section on recettes d'investissement, which includes "
#  'subventions, emprunts, and some reports. They mention an avance du budget '
#  'général to balance the section. \n'
#  '\n'
#  "I'm getting a bit confused with all the pluses and minuses. Are these "
#  'adjustments being made to the previous DM3? So, the numbers in the middle '
#  'column are the previous amounts, and the last column is the adjustment? So, '
#  'the total would be the middle column plus the last column?\n'
#  '\n'
#  'Also, the amortissements seem to be a recurring theme, both in revenues and '
#  'expenses. I think amortissement is like depreciation, spreading the cost '
#  "over time. So, when they mention compléments pour l'amortissement des "
#  "subventions, they're probably adjusting the depreciation of subsidies "
#  'received.\n'
#  '\n'
#  "The user mentioned that the assistant's response was correct, so I think I'm "
#  "on the right track. But I'm still unclear on how the negative numbers affect "
#  'the totals. Maybe they are reductions, so you subtract them from the '
#  'previous amounts. For example, in recettes, the total is 1,006,710, but then '
#  'subtract 115,464 and 57,600? Or is it just the net change from DM3?\n'
#  '\n'
#  'I should probably summarize each section, explaining the main adjustments '
#  'and how they affect the totals. Make sure to highlight the key points like '
#  'the decrease in the general budget subsidy and the reports to 2022. Also, '
#  'note the use of avance du budget général to balance the investment section.\n'
#  '\n'
#  'I think the user wants a clear breakdown of what each section means, '
#  'focusing on the significant adjustments and their financial impact. They '
#  'might be looking for a summary to understand the budget changes without '
#  'getting lost in the details.\n'
#  '</think>\n'
#  '\n'
#  'The budget document for BP 2021 outlines various adjustments and financial '
#  "movements across both operational and investment sections. Here's a "
#  'structured summary of the key points:\n'
#  '\n'
#  '### Operational Revenues (Recettes)\n'
#  '\n'
#  '1. **Produits des services (70):** \n'
#  '   - Initial amount: €311,000.\n'
#  '   - Adjustment: Decrease by €125,000.\n'
#  '\n'
#  '2. **Dotations et subventions (74):**\n'
#  '   - Initial amount: €124,600.\n'
#  '   - Adjustments: Decrease by €31,000 and a further €20,400.\n'
#  '\n'
#  '3. **Autres produits (75):**\n'
#  '   - Initial amount: €571,110.\n'
#  '   - Adjustments: Small decrease and a significant decrease of €80,500.\n'
#  '\n'
#  '4. **Total Recettes Réelles:**\n'
#  '   - €1,006,710 with adjustments of -€115,464 and -€57,600.\n'
#  '\n'
#  '5. **Amortissements:**\n'
#  '   - Additional €10,000, leading to a total of €1,016,710.\n'
#  '\n'
#  "### Investment Expenditures (Dépenses d'Investissement)\n"
#  '\n'
#  '1. **Emprunts et dettes (16):**\n'
#  '   - Initial: €49,600.\n'
#  '   - Adjustments: Increase to €381,650, then decrease by €382,250.\n'
#  '\n'
#  '2. **Matériels et travaux aéroport (601 & 608):**\n'
#  '   - Significant expenditures with specific allocations for equipment and '
#  'construction.\n'
#  '\n'
#  '3. **Total Dépenses Réelles:**\n'
#  '   - €462,900 with amortissements adding to the total.\n'
#  '\n'
#  "### Investment Revenues (Recettes d'Investissement)\n"
#  '\n'
#  '1. **Subventions (13):**\n'
#  '   - Initial: €195,000.\n'
#  '   - Adjustments: Decrease by €275,000.\n'
#  '\n'
#  '2. **Emprunts:**\n'
#  '   - Initial: €1,064,275.\n'
#  '   - Adjustments: Decrease by €771,650, with an avance du budget général of '
#  '€292,625.\n'
#  '\n'
#  '3. **Total:**\n'
#  '   - Balancing the section with an avance du budget général.\n'
#  '\n'
#  '### Key Adjustments and Impacts\n'
#  '\n'
#  '- **Amortissements des subventions:** Adjustments for depreciation of '
#  'subsidies are noted in both revenues and expenses.\n'
#  '- **Reports to 2022:** Significant reports include road diversion and other '
#  'projects, impacting the current budget.\n'
#  '- **Avance du budget général:** Used to balance the investment section, '
#  'indicating inter-budgetary adjustments.\n'
#  '\n'
#  'This summary provides a clear overview of the financial adjustments and '
#  'their implications for the BP 2021 budget.')
#
#
# --------------------------------
# SUMMARY OF page_29.pdf with model: gemma2-9b-it
# ('## Analyse du budget\n'
#  '\n'
#  "Les informations fournies semblent correspondre à un extrait du budget d'un "
#  'aéroport, regroupant les données des recettes et dépenses. \n'
#  '\n'
#  "Voici un résumé et quelques éléments d'analyse :\n"
#  '\n'
#  '**Points importants :**\n'
#  '\n'
#  "* **Mutation du compte d'exploitation:** Le budget présente une tendance "
#  'positive avec une augmentation des recettes et une diminution des dépenses '
#  "par rapport à l'année précédente. L'augmentation des recettes provient "
#  'principalement de "Produits des services" et  "Autres produits de gestion '
#  'courante". La diminution des dépenses est due à des ajustements notamment '
#  'sur les amortissements. \n'
#  '\n'
#  '* **Investissement :** Le budget prévoit des investissements importants, '
#  'notamment pour  le développement aéroportuaire ("travaux d\'alimentation '
#  'électrique", "constructions de hangars"). Cependant, certains projets prévus '
#  'en 2021 ont été reportés à 2022 (déviation de la route, création de la '
#  'nouvelle ligne aérienne).\n'
#  '* **Financement :** La section investissement est financée en partie par des '
#  "subventions, des emprunts et des prélèvements sur l'avance du budget "
#  "général. L'annulation d'un emprunt inscrit au budget influence positivement "
#  'le financement.\n'
#  '\n'
#  '**Questions à se poser :**\n'
#  '\n'
#  "* **Nature des services produits :** Quel type de services l'aéroport "
#  "propose-t-il pour justifier l'augmentation des recettes ?\n"
#  '* **Impact des report de projets :** Quels sont les raisons des reports et '
#  'quelles sont les conséquences sur le plan économique et de développement de '
#  "l'aéroport ? \n"
#  "* **Gestion des subventions :** Comment l'aéroport gère-t-il les limitations "
#  'liées aux subventions et comment assure-t-il le financement des projets '
#  'importants ?\n'
#  "* **Risques financiers :** Quel est le niveau de dépendance à l'avance du "
#  'budget général et quelles sont les implications pour la trésorerie de '
#  "l'aéroport ?\n"
#  '\n'
#  '**Recommandations :**\n'
#  '\n'
#  '* Un analyse plus approfondie du budget est nécessaire pour comprendre '
#  "pleinement les enjeux et les décisions stratégiques de l'aéroport.\n"
#  '* Il serait utile de comparer les données du budget avec celles des années '
#  'précédentes et anticiper les défis et les opportunités futures.\n'
#  '\n'
#  "**N'hésitez pas à me fournir plus de contexte ou de questions pour "
#  "approfondir l'analyse.** \n"
#  '\n'
#  '\n')
#
#
# --------------------------------
# SUMMARY OF page_29.pdf with model: llama-3.3-70b-versatile
# ("Il semble que nous ayons affaire à un document budgétaire d'une collectivité "
#  "ou d'une entreprise, probablement lié à la gestion d'un aéroport. Le "
#  "document présente les recettes et les dépenses pour l'année 2021, ainsi que "
#  'les modifications apportées par rapport aux précédentes décisions '
#  'modificatives (DM).\n'
#  '\n'
#  'Voici une synthèse des principaux points :\n'
#  '\n'
#  '**Recettes**\n'
#  '\n'
#  "* Les recettes totales s'élèvent à 1 016 710 €, en diminution de 115 464 € "
#  'par rapport aux précédentes décisions modificatives.\n'
#  '* Les principaux postes de recettes sont :\n'
#  ' + Produits des services : 311 000 €\n'
#  ' + Dotations, subventions et participations : 124 600 €\n'
#  ' + Autres produits de gestion courante : 571 110 €\n'
#  '* Il y a également des reprises sur amortissements et provisions pour un '
#  'montant de 12 486 €.\n'
#  '\n'
#  '**Dépenses**\n'
#  '\n'
#  "* Les dépenses totales s'élèvent à 472 900 €, en diminution de 1 528 467 € "
#  'par rapport aux précédentes décisions modificatives.\n'
#  '* Les principaux postes de dépenses sont :\n'
#  ' + Emprunts et dettes : 49 600 €\n'
#  ' + Immobilisations corporelles : 138 300 €\n'
#  ' + Autres travaux aéroport : 275 000 €\n'
#  '* Il y a également des amortissements pour un montant de 10 000 € et des '
#  'opérations patrimoniales pour un montant de 3 100 €.\n'
#  '\n'
#  "**Recettes d'investissement**\n"
#  '\n'
#  "* Les recettes d'investissement s'élèvent à 195 000 €, en diminution de 275 "
#  '000 € par rapport aux précédentes décisions modificatives.\n'
#  "* Les principaux postes de recettes d'investissement sont :\n"
#  ' + Subventions : 195 000 €\n'
#  ' + Emprunts : 1 064 275 € (mais avec une annulation de 771 650 €)\n'
#  ' + Avance du budget général : 292 625 €\n'
#  '\n'
#  'Il semble que le budget ait été révisé pour prendre en compte des '
#  'modifications dans les recettes et les dépenses, notamment en ce qui '
#  "concerne les travaux d'investissement et les emprunts. Il est possible que "
#  'ces modifications soient liées à des changements dans les priorités de la '
#  "collectivité ou de l'entreprise, ou à des contraintes financières.")
#
#
# --------------------------------

# %% [markdown]
# Note for Ziyan: do the first 2 pages, I will do the other 2.
#
#
#
# Maybe write a couple of general comments on the length of the summaries,
#
# whether they include info that is useful (although it may be the case that those pages are just not that important)
#
# things the summaries missed, etc. No need to make it too long.

# %% [markdown]
# ## Evaluation of the Table Context

# %%
from council_rag.data_transformations.table_transformations import convert_pdf_to_image, augment_multimodal_context
from pprint import pprint
import os

# %%
# paste the GROQ_KEY.txt file in the same folder as this notebook
with open("GROQ_KEY.txt", "r") as file:
    groq_key = file.read()

# %%
base_multi_prompt = """CONTEXTE
L'image suivante contient une page et un tableau. 

TÂCHE
Décrivez le tableau et le contenu de la page en accordant une attention particulière au contexte qui l'entoure, qu'il s'agisse de budgets, de dates, d'élections, d'agendas, de projets futurs ou de sujets connexes. 

FORMAT DE LA RÉPONSE
Votre réponse doit être aussi détaillée que possible. 
Votre résultat doit être la description du tableau directement.
La langue de votre réponse est le français"""

# %%
eval_table_cont_data_path = "Evaluation data/Table Context/"
eval_table_cont_random_pages = os.listdir(eval_table_cont_data_path)
print(eval_table_cont_random_pages)
# Out:
# ['page_10.pdf', 'page_29.pdf', 'page_36.pdf', 'page_43.pdf', 'page_9.pdf']

# %%
paths = [eval_table_cont_data_path + pdf_path for pdf_path in eval_table_cont_random_pages]

# %%
paths[:2]
# Out:
# ['Evaluation data/Table Context/page_10.pdf',
#  'Evaluation data/Table Context/page_29.pdf']

# %%
images_paths = [convert_pdf_to_image(pdf_path) for pdf_path in paths]

for im_path in images_paths:
    resp = augment_multimodal_context(im_path, 
                                        base_multi_prompt, 
                                        groq_key,
                                        model="llama-3.2-11b-vision-preview")
    
    print("TABLE DESCRIPTION OF {} with model: {}".format(im_path, "llama-3.2-11b-vision"))
    pprint(resp)
    print("\n")
    print("--------------------------------")
        
    # if you prefer openning the txt file instead of reading below. will save into the Evaluation data/Summaries folder
    with open(f"llama-3.2-11b-vision_table_descr__{im_path}.txt") as f: 
        f.write(summ)

# %% [markdown]
# ## Evaluation of Embeddings via Clustering Distance

# %%
from council_rag.preprocessing import split_markdown_to_paras, compute_paragraph_embeddings
from pprint import pprint
import os
import torch
import numpy as np

# %%
device = "cpu"
if torch.cuda.is_available():
    # print("Cuda available")
    device = torch.device('cuda')

# %%
[os.path.join(final_eval_pdfs_path, pdf) for pdf in final_eval_pdfs

# %%
eval_clust_path = r"Evaluation data\PDFs for Clustering Eval wrt Embed Model"
list_txts = [txt for txt in os.listdir(eval_clust_path) if txt.endswith(".txt")]
list_txts_paths = [os.path.join(eval_clust_path, txt) for txt in list_txts]
list_txts_paths
# Out:
# ['Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\08d25_DEL-2023-171_Annexe_Rapport_developpment_durable_2021-2022.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\09541_pagedoc_1503_B.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\40b835f11d17fb2a29780f5702b5def19b97d4ef_RA-2021_ALEC-POL.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\44581100d4d00d982967f67297858d20b40cb9d8_Programme-LEADER.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\ace41990e2df7de61ced4b55c88c215810403448_20230302_PLUi_PA.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\cc7329f0f9d289cba48647ce810b5aa7e02189c0_9ccf7c_35ac2a46e.txt',
#  'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\e9442_Photovoltaique-20230711-012221-6.txt']

# %%
dict_file_txt = {}
for txt_file in list_txts_paths:
    with open(txt_file, "r") as f:
        text = f.read()
        
    paragraphs = split_markdown_to_paras(text, spacy_model="fr_core_news_sm", n_sents_per_para=10)
    print("Num of paragraphs in the text:")
    print(len(paragraphs))
    # check len of paragraphs
    quick_len_check = lambda x: len(x.split(" "))
    n_tokens = []
    txt_paras = []
    for paragraph in paragraphs:
        n_toks = quick_len_check(paragraph["paragraph_union"])
        # print(n_toks)
        n_tokens.append(n_toks)
        para_txt = paragraph["paragraph_union"]
        txt_paras.append(para_txt)
    max_toks = np.max(n_tokens)
    dict_file_txt[txt_file] = {
                                "max_tokens":max_toks,
                                "para_list_text": txt_paras
                            }
    print("Max. number of naive tokens in a sentence: ", max_toks)
# Out:
# Num of paragraphs in the text:
# 67
# Max. number of naive tokens in a sentence:  1111
# Num of paragraphs in the text:
# 19
# Max. number of naive tokens in a sentence:  260
# Num of paragraphs in the text:
# 30
# Max. number of naive tokens in a sentence:  344
# Num of paragraphs in the text:
# 160
# Max. number of naive tokens in a sentence:  383
# Num of paragraphs in the text:
# 127
# Max. number of naive tokens in a sentence:  306
# Num of paragraphs in the text:
# 28
# Max. number of naive tokens in a sentence:  328
# Num of paragraphs in the text:
# 11
# Max. number of naive tokens in a sentence:  267

# %% [markdown]
# The number of artificial paragraphs varies as expected since we have pdfs of different sizes.
#
# The max number of tokens is usually around 260-360.

# %%
dict_file_txt.keys()
# dictionary with the txt files as keys and their max number of tokens an list of paragraphs as values
# Out:
# dict_keys(['Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\08d25_DEL-2023-171_Annexe_Rapport_developpment_durable_2021-2022.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\09541_pagedoc_1503_B.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\40b835f11d17fb2a29780f5702b5def19b97d4ef_RA-2021_ALEC-POL.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\44581100d4d00d982967f67297858d20b40cb9d8_Programme-LEADER.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\ace41990e2df7de61ced4b55c88c215810403448_20230302_PLUi_PA.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\cc7329f0f9d289cba48647ce810b5aa7e02189c0_9ccf7c_35ac2a46e.txt', 'Evaluation data\\PDFs for Clustering Eval wrt Embed Model\\e9442_Photovoltaique-20230711-012221-6.txt'])

# %% [markdown]
# MTEB(fra, v1) BenchMark: http://mteb-leaderboard.hf.space/?benchmark_name=MTEB%28fra%2C+v1%29

# %% [markdown]
# https://huggingface.co/dangvantuan/sentence-camembert-large
#
# https://huggingface.co/Salesforce/SFR-Embedding-2_R - highest in the clustering tasks in the benchmark
#
# https://huggingface.co/manu/sentence_croissant_alpha_v0.4 - not highest but probably faster
#
# https://huggingface.co/Snowflake/snowflake-arctic-embed-l-v2.0
#
# https://huggingface.co/flaubert/flaubert_base_uncased
#
# antoinelouis/crossencoder-camembert-base-mmarcoFR - reranker in french
#
# https://huggingface.co/jinaai/jina-embeddings-v3 - has different types of embedding functions

# %%
model_candidates = ["HIT-TMG/KaLM-embedding-multilingual-mini-v1", 
                    "all-MiniLM-L6-v2", 
                    "dangvantuan/sentence-camembert-large",
                    "Snowflake/snowflake-arctic-embed-l-v2.0",
                    "jinaai/jina-embeddings-v3",
                    "flaubert-large-cased", 
                    "Salesforce/SFR-Embedding-2_R",
                    "manu/sentence_croissant_alpha_v0.4"
                    ]

# %%
from sentence_transformers import SentenceTransformer

model_id ="HIT-TMG/KaLM-embedding-multilingual-mini-v1"

paragraphs = compute_paragraph_embeddings(paragraphs, model_id)

# %%
from council_rag.preprocessing import get_optimal_n_clusters
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from council_rag.preprocessing import cluster_n
#
# ImportError: cannot import name 'cluster_n' from 'council_rag.preprocessing' (c:\Users\alber\Desktop\Council-Minutes\Alberto Research\RAGTOR\council_rag\preprocessing\__init__.py)

# %%
optimal_n, final_clusters = get_optimal_n_clusters(embeddings, max_n_clusters=9)
